# %%
#6/5/2026 Wednessday

import pandas as pd
import numpy as np
from dateutil import parser
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
#create messy raw data
#This dataset is in dictionary data type => key : value pairs
data = {
    "EmpId": [101, 102, "103", 104, 105, 106, 107, 108, 109, 110],
    "fullName": [
        "  Alice Johnson  ", "MICHEAL smith", "sarah lee", "David-Kim", None, "john brown",
        "Emma Wilson", "TOM  davis", "Jane Miller", "Chris taylor"
    ], 
     "Dept": ["IT", "hr", "Mktng", "IT", "Customer Care", "marketing", "Finance", None, "HR", "marketing"],
    "Age": [29, "thirty-five", 26, 31, 42, 27, 33, 30, None, 28],
    "Salary($)": ["$5500.50", "4800", "4200.75", "NaN", "6100", "4,300", "5800", "5000", "4700.0", "4400"],
    "JoinDate" : [ 
        "12-04-2021" , "2020.11.01" , "Jan 18, 2022" , "2019/9/25" , "07/05/18" , "2021-10-14" , 
        "2019/12/01" , "2020-03-22" , "May 10th, 2021" , "2022-02-05" 
    ],
    "Performance": [87, "73", 90, 65, 82, 75, 88, None, "79%", "91"],
    "Remote?": ["Yes", "No", "Y", "N", "yes", "no", "Y", "Yes", None, "True"]
}

# %%
# To convert raw data set to dataframe dataset
data_frame = pd.DataFrame(data)

data_frame
# Out:
#   EmpId           fullName           Dept          Age Salary($)  \
# 0   101    Alice Johnson               IT           29  $5500.50
# 1   102      MICHEAL smith             hr  thirty-five      4800
# 2   103          sarah lee          Mktng           26   4200.75
# 3   104          David-Kim             IT           31       NaN
# 4   105                NaN  Customer Care           42      6100
# 5   106         john brown      marketing           27     4,300
# 6   107        Emma Wilson        Finance           33      5800
# 7   108         TOM  davis            NaN           30      5000
# 8   109        Jane Miller             HR         None    4700.0
# 9   110       Chris taylor      marketing           28      4400
#
#          JoinDate Performance Remote?
# 0      12-04-2021          87     Yes
# 1      2020.11.01          73      No
# 2    Jan 18, 2022          90       Y
# 3       2019/9/25          65       N
# 4        07/05/18          82     yes
# ...

# %%
# Convert dataframe into csv file  to_csv()
# Create a folder (data) on your vs code to save the employee_dataset in a folder
# You can also save it without creating any folder, just that you won't add data to the instruction given to your code. 
# index=False => not to include the index numbers 

data_frame.to_csv("data/employee_dataset.csv", index=False)

# %%
# Load a csv file on pandas
# every file has its own loading format
# csv => read_csv()
# excel => read_excel()

#Load csv file dataset on pandas 
df = pd.read_csv("data/employee_dataset.csv")

df
# Out:
#    EmpId           fullName           Dept          Age Salary($)  \
# 0    101    Alice Johnson               IT           29  $5500.50
# 1    102      MICHEAL smith             hr  thirty-five      4800
# 2    103          sarah lee          Mktng           26   4200.75
# 3    104          David-Kim             IT           31       NaN
# 4    105                NaN  Customer Care           42      6100
# 5    106         john brown      marketing           27     4,300
# 6    107        Emma Wilson        Finance           33      5800
# 7    108         TOM  davis            NaN           30      5000
# 8    109        Jane Miller             HR          NaN    4700.0
# 9    110       Chris taylor      marketing           28      4400
#
#          JoinDate Performance Remote?
# 0      12-04-2021          87     Yes
# 1      2020.11.01          73      No
# 2    Jan 18, 2022          90       Y
# 3       2019/9/25          65       N
# 4        07/05/18          82     yes
# ...

# %%
# Explore and data cleaning   .info()
#check the info of the dataset 

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   EmpId        10 non-null     int64
#  1   fullName     9 non-null      str
#  2   Dept         9 non-null      str
#  3   Age          9 non-null      str
#  4   Salary($)    9 non-null      str
#  5   JoinDate     10 non-null     str
#  6   Performance  9 non-null      str
#  7   Remote?      9 non-null      str
# dtypes: int64(1), str(7)
# memory usage: 772.0 bytes

# %%
#Shape will let you known the numbers of rows and colunms you have in the dataset
#Shape(row, colunm)  .shape

df.shape
# Out:
# (10, 8)

# %%
# To display part of the dataset 
# get the fisrt five rows from the dataset => .head() 
# pass the number of the data set you want to view in to the .head(10), if its less than or more than 5 bcos 5 is the default value.
df.head()
# Out:
#    EmpId           fullName           Dept          Age Salary($)  \
# 0    101    Alice Johnson               IT           29  $5500.50
# 1    102      MICHEAL smith             hr  thirty-five      4800
# 2    103          sarah lee          Mktng           26   4200.75
# 3    104          David-Kim             IT           31       NaN
# 4    105                NaN  Customer Care           42      6100
#
#        JoinDate Performance Remote?
# 0    12-04-2021          87     Yes
# 1    2020.11.01          73      No
# 2  Jan 18, 2022          90       Y
# 3     2019/9/25          65       N
# 4      07/05/18          82     yes

# %%
#get the dataset colunms  => .columns
df.columns
# Out:
# Index(['EmpId', 'fullName', 'Dept', 'Age', 'Salary($)', 'JoinDate',
#        'Performance', 'Remote?'],
#       dtype='str')

# %%
#check missing value  => .isnull()

# To calculate the total missing values in the dataset  =>  .isnull().sum()
df.isnull().sum()

# To list theS missing values in the dataset  =>  .isnull()
df.isnull()
# Out:
#    EmpId  fullName   Dept    Age  Salary($)  JoinDate  Performance  Remote?
# 0  False     False  False  False      False     False        False    False
# 1  False     False  False  False      False     False        False    False
# 2  False     False  False  False      False     False        False    False
# 3  False     False  False  False       True     False        False    False
# 4  False      True  False  False      False     False        False    False
# 5  False     False  False  False      False     False        False    False
# 6  False     False  False  False      False     False        False    False
# 7  False     False   True  False      False     False         True    False
# 8  False     False  False   True      False     False        False     True
# 9  False     False  False  False      False     False        False    False

# %%
#inspect unique values in colunms
#pandas represents none value as nan (NaN) and blank space as nan (NaN)
print(df["Dept"].unique())
print(df["Age"].unique())
print(df["Remote?"].unique())
# Out:
# <StringArray>
# ['IT', 'hr', 'Mktng', 'Customer Care', 'marketing', 'Finance', nan, 'HR']
# Length: 8, dtype: str
# <StringArray>
# ['29', 'thirty-five', '26', '31', '42', '27', '33', '30', nan, '28']
# Length: 10, dtype: str
# <StringArray>
# ['Yes', 'No', 'Y', 'N', 'yes', 'no', nan, 'True']
# Length: 8, dtype: str

# %%
#access salary value 
# series format  df["Salary($)"]
# list format df["Salary($)"].to_list()
df["Salary($)"].to_list()
# Out:
# ['$5500.50',
#  '4800',
#  '4200.75',
#  nan,
#  '6100',
#  '4,300',
#  '5800',
#  '5000',
#  '4700.0',
#  '4400']

# %%
#7/5/2026 Thursday
df["fullName"].to_list()
# Out:
# ['  Alice Johnson  ',
#  'MICHEAL smith',
#  'sarah lee',
#  'David-Kim',
#  nan,
#  'john brown',
#  'Emma Wilson',
#  'TOM  davis',
#  'Jane Miller',
#  'Chris taylor']

# %%
df["Salary($)"].head()
# Out:
# 0    $5500.50
# 1        4800
# 2     4200.75
# 3         NaN
# 4        6100
# Name: Salary($), dtype: str

# %%
#Data cleaning 
#

df.rename(columns={
    "EmpId" : "Employment ID" , 
    "fullName" : "Full Name" ,
    "Dept" : "Department" ,
    "Age" : "Age" ,
    "Salary($)" : "Salary" ,
    "JoinDate" : "Join Date" ,
    "Performance" : "Performance" ,
    "Remote?" : "Remote"
} , inplace=True)

df
# Out:
#    Employment ID          Full Name     Department          Age    Salary  \
# 0            101    Alice Johnson               IT           29  $5500.50
# 1            102      MICHEAL smith             hr  thirty-five      4800
# 2            103          sarah lee          Mktng           26   4200.75
# 3            104          David-Kim             IT           31       NaN
# 4            105                NaN  Customer Care           42      6100
# 5            106         john brown      marketing           27     4,300
# 6            107        Emma Wilson        Finance           33      5800
# 7            108         TOM  davis            NaN           30      5000
# 8            109        Jane Miller             HR          NaN    4700.0
# 9            110       Chris taylor      marketing           28      4400
#
#         Join Date Performance Remote
# 0      12-04-2021          87    Yes
# 1      2020.11.01          73     No
# 2    Jan 18, 2022          90      Y
# ...

# %%
#Cleaning inconsistence values on full name
df["Full Name"].to_list()
# Out:
# ['  Alice Johnson  ',
#  'MICHEAL smith',
#  'sarah lee',
#  'David-Kim',
#  nan,
#  'john brown',
#  'Emma Wilson',
#  'TOM  davis',
#  'Jane Miller',
#  'Chris taylor']

# %%
# .strip() is used to remove spaces before and after from the strings object
# .title is used to capitalized first letter in a character
# .replace to replace a value 
# (r"[\s-]+", " ", regex=True)
# .str mean strings
df["Full Name"] = (
    df["Full Name"]
    .str.strip()
    .str.title()
    .str.replace(r"[\s-]+", " ", regex=True)
)
df["Full Name"].to_list()
# Out:
# ['Alice Johnson',
#  'Micheal Smith',
#  'Sarah Lee',
#  'David Kim',
#  nan,
#  'John Brown',
#  'Emma Wilson',
#  'Tom Davis',
#  'Jane Miller',
#  'Chris Taylor']

# %%
#Cleaning inconsistence values on Department
df["Department"].to_list()
# Out:
# ['IT',
#  'hr',
#  'Mktng',
#  'IT',
#  'Customer Care',
#  'marketing',
#  'Finance',
#  nan,
#  'HR',
#  'marketing']

# %%
# replace 

df.replace({
    "hr" : "HR",
    "Mktng" : "Marketing",
    "marketing" : "Marketing",
    None : np.nan
}, inplace=True)

df["Department"]
# Out:
# 0               IT
# 1               HR
# 2        Marketing
# 3               IT
# 4    Customer Care
# 5        Marketing
# 6          Finance
# 7              NaN
# 8               HR
# 9        Marketing
# Name: Department, dtype: str

# %%
# Cleaning inconsistence value in Age
df["Age"].to_list()
# Out:
# ['29', 'thirty-five', '26', '31', '42', '27', '33', '30', nan, '28']

# %%
# Custom function to clean a 
# .apply() function will allow the changes on pandas

def clean_age(value): 
    if value == "thirty-five":
        return 35
    elif isinstance(value, (int, float)):
        return value
    elif isinstance(value, str) and value.isdigit():
        return int(value)
    else:
        return np.nan

df["Age"] = df["Age"].apply(clean_age)

df["Age"]
# Out:
# 0    29.0
# 1    35.0
# 2    26.0
# 3    31.0
# 4    42.0
# 5    27.0
# 6    33.0
# 7    30.0
# 8     NaN
# 9    28.0
# Name: Age, dtype: float64

# %%
# assignment 
# Clean Salary, Performance and remote

# %%
#Cleaning inconsistence value in Salary
#df["Salary"].to_list() => display all the values in the data set 
#df["Salary"].unique() => display only the unique value in the data set 
#df["Salary"]. head() => display first 5 rows value inthe data set 
df["Salary"].to_list()
# Out:
# ['$5500.50',
#  '4800',
#  '4200.75',
#  nan,
#  '6100',
#  '4,300',
#  '5800',
#  '5000',
#  '4700.0',
#  '4400']

# %%
#Cleaning inconsistence value in Salary
# .astype() to convert string value to integer/float value
df["Salary"] = (
    df["Salary"]
    .astype(str)
    .replace(r"[$,]", "", regex=True)
    .replace("NaN", np.nan)
    .astype(float)
)

df["Salary"]
# Out:
# 0    5500.50
# 1    4800.00
# 2    4200.75
# 3        NaN
# 4    6100.00
# 5    4300.00
# 6    5800.00
# 7    5000.00
# 8    4700.00
# 9    4400.00
# Name: Salary, dtype: float64

# %%
#Cleaning inconsistence value in Performance
df["Performance"].to_list()
# Out:
# ['87', '73', '90', '65', '82', '75', '88', nan, '79%', '91']

# %%
#Cleaning inconsistence value in Performance

df["Performance"] = (
    df["Performance"]
    .astype(str)
    .replace(r"%", "", regex=True)
    .replace("None", np.nan)
    .astype(float)
    
)

df["Performance"]
# Out:
# 0    87.0
# 1    73.0
# 2    90.0
# 3    65.0
# 4    82.0
# 5    75.0
# 6    88.0
# 7     NaN
# 8    79.0
# 9    91.0
# Name: Performance, dtype: float64

# %%
#Cleaning inconsistence value in Remote

df["Remote"].to_list()
# Out:
# ['Yes', 'No', 'Y', 'N', 'yes', 'no', 'Y', 'Yes', nan, 'True']

# %%
#Cleaning inconsistence value in Remote 

df.replace({
        "Y" : "Yes",
        "N" : "No",
        "yes" : "Yes",
        "no" : "No",
        "None" : np.nan,
        "True" : "Yes"
    }, inplace=True)


df["Remote"]
# Out:
# 0    Yes
# 1     No
# 2    Yes
# 3     No
# 4    Yes
# 5     No
# 6    Yes
# 7    Yes
# 8    NaN
# 9    Yes
# Name: Remote, dtype: str

# %%
#cleaning inconsistence value in join_date column
# df.to_datetime()  
df["Join Date"].to_list()
# Out:
# ['12-04-2021',
#  '2020.11.01',
#  'Jan 18, 2022',
#  '2019/9/25',
#  '07/05/18',
#  '2021-10-14',
#  '2019/12/01',
#  '2020-03-22',
#  'May 10th, 2021',
#  '2022-02-05']

# %%
#cleaning inconsistence value in join_date column
# df.to_datetime() 
#df["Join Date"] = pd.to_datetime(df["Join Date"], errors="coerce")
#df["Join Date"]
# date utility handle any complex date format

def date_parser(date_str):
    try:
        return parser.parse(date_str, dayfirst=True)
    except Exception:
        return pd.NaT
df["Join Date"] = df["Join Date"].apply(date_parser)

df["Join Date"]
# Out:
# 0   2021-04-12
# 1   2020-01-11
# 2   2022-01-18
# 3   2019-09-25
# 4   2018-05-07
# 5   2021-10-14
# 6   2019-01-12
# 7   2020-03-22
# 8   2021-05-10
# 9   2022-05-02
# Name: Join Date, dtype: datetime64[us]

# %%
#12/5/2026  TUESDAY
#cleaning inconsistence value in Employment ID column
# to_numeric()  => to convert a string value to a numerical value 

df["Employment ID"] = pd.to_numeric(df["Employment ID"], errors="coerce")

df["Employment ID"]
# Out:
# 0    101
# 1    102
# 2    103
# 3    104
# 4    105
# 5    106
# 6    107
# 7    108
# 8    109
# 9    110
# Name: Employment ID, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Employment ID  10 non-null     int64
#  1   Full Name      9 non-null      str
#  2   Department     9 non-null      str
#  3   Age            9 non-null      float64
#  4   Salary         9 non-null      float64
#  5   Join Date      10 non-null     datetime64[us]
#  6   Performance    9 non-null      float64
#  7   Remote         9 non-null      str
# dtypes: datetime64[us](1), float64(3), int64(1), str(3)
# memory usage: 772.0 bytes

# %%
df
# Out:
#    Employment ID      Full Name     Department   Age   Salary  Join Date  \
# 0            101  Alice Johnson             IT  29.0  5500.50 2021-04-12
# 1            102  Micheal Smith             HR  35.0  4800.00 2020-01-11
# 2            103      Sarah Lee      Marketing  26.0  4200.75 2022-01-18
# 3            104      David Kim             IT  31.0      NaN 2019-09-25
# 4            105            NaN  Customer Care  42.0  6100.00 2018-05-07
# 5            106     John Brown      Marketing  27.0  4300.00 2021-10-14
# 6            107    Emma Wilson        Finance  33.0  5800.00 2019-01-12
# 7            108      Tom Davis            NaN  30.0  5000.00 2020-03-22
# 8            109    Jane Miller             HR   NaN  4700.00 2021-05-10
# 9            110   Chris Taylor      Marketing  28.0  4400.00 2022-05-02
#
#    Performance Remote
# 0         87.0    Yes
# 1         73.0     No
# 2         90.0    Yes
# 3         65.0     No
# 4         82.0    Yes
# 5         75.0     No
# ...

# %%
#handling misisng values in Full Name colunm
#fillna() is used to replaced a missing value in a particular column, based on condition or alteration method
# .fillna()
df["Full Name"] = df["Full Name"].fillna("Unknown")

df["Full Name"]
# Out:
# 0    Alice Johnson
# 1    Micheal Smith
# 2        Sarah Lee
# 3        David Kim
# 4          Unknown
# 5       John Brown
# 6      Emma Wilson
# 7        Tom Davis
# 8      Jane Miller
# 9     Chris Taylor
# Name: Full Name, dtype: str

# %%
#handling misisng values in Department colunm
df["Department"] = df["Department"].fillna(df["Department"].mode()[0])

df["Department"]
# Out:
# 0               IT
# 1               HR
# 2        Marketing
# 3               IT
# 4    Customer Care
# 5        Marketing
# 6          Finance
# 7        Marketing
# 8               HR
# 9        Marketing
# Name: Department, dtype: str

# %%
#handling misisng values in Age colunm
df["Age"] = df["Age"].fillna(df["Age"].median())
df["Age"]
# Out:
# 0    29.0
# 1    35.0
# 2    26.0
# 3    31.0
# 4    42.0
# 5    27.0
# 6    33.0
# 7    30.0
# 8    30.0
# 9    28.0
# Name: Age, dtype: float64

# %%
#handling misisng values in Salary colunm
df["Salary"] = df["Salary"].fillna(df["Salary"].median())

df["Salary"]
# Out:
# 0    5500.50
# 1    4800.00
# 2    4200.75
# 3    4800.00
# 4    6100.00
# 5    4300.00
# 6    5800.00
# 7    5000.00
# 8    4700.00
# 9    4400.00
# Name: Salary, dtype: float64

# %%
#handling misisng values in Performance colunm

df["Performance"] = df["Performance"].fillna(df["Performance"].median())

df["Performance"]
# Out:
# 0    87.0
# 1    73.0
# 2    90.0
# 3    65.0
# 4    82.0
# 5    75.0
# 6    88.0
# 7    82.0
# 8    79.0
# 9    91.0
# Name: Performance, dtype: float64

# %%
#handling misisng values in Remote colunm

df["Remote"] = df["Remote"].fillna(df["Remote"].mode()[0])

df["Remote"]
# Out:
# 0    Yes
# 1     No
# 2    Yes
# 3     No
# 4    Yes
# 5     No
# 6    Yes
# 7    Yes
# 8    Yes
# 9    Yes
# Name: Remote, dtype: str

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Employment ID  10 non-null     int64
#  1   Full Name      10 non-null     str
#  2   Department     10 non-null     str
#  3   Age            10 non-null     float64
#  4   Salary         10 non-null     float64
#  5   Join Date      10 non-null     datetime64[us]
#  6   Performance    10 non-null     float64
#  7   Remote         10 non-null     str
# dtypes: datetime64[us](1), float64(3), int64(1), str(3)
# memory usage: 772.0 bytes

# %%
df
# Out:
#    Employment ID      Full Name     Department   Age   Salary  Join Date  \
# 0            101  Alice Johnson             IT  29.0  5500.50 2021-04-12
# 1            102  Micheal Smith             HR  35.0  4800.00 2020-01-11
# 2            103      Sarah Lee      Marketing  26.0  4200.75 2022-01-18
# 3            104      David Kim             IT  31.0  4800.00 2019-09-25
# 4            105        Unknown  Customer Care  42.0  6100.00 2018-05-07
# 5            106     John Brown      Marketing  27.0  4300.00 2021-10-14
# 6            107    Emma Wilson        Finance  33.0  5800.00 2019-01-12
# 7            108      Tom Davis      Marketing  30.0  5000.00 2020-03-22
# 8            109    Jane Miller             HR  30.0  4700.00 2021-05-10
# 9            110   Chris Taylor      Marketing  28.0  4400.00 2022-05-02
#
#    Performance Remote
# 0         87.0    Yes
# 1         73.0     No
# 2         90.0    Yes
# 3         65.0     No
# 4         82.0    Yes
# 5         75.0     No
# ...

# %%
#working with filtering

df["Full Name"]
# Out:
# 0    Alice Johnson
# 1    Micheal Smith
# 2        Sarah Lee
# 3        David Kim
# 4          Unknown
# 5       John Brown
# 6      Emma Wilson
# 7        Tom Davis
# 8      Jane Miller
# 9     Chris Taylor
# Name: Full Name, dtype: str

# %%
#working with filtering 
df.head()
# only filtering the first 5 rows
# Out:
#    Employment ID      Full Name     Department   Age   Salary  Join Date  \
# 0            101  Alice Johnson             IT  29.0  5500.50 2021-04-12
# 1            102  Micheal Smith             HR  35.0  4800.00 2020-01-11
# 2            103      Sarah Lee      Marketing  26.0  4200.75 2022-01-18
# 3            104      David Kim             IT  31.0  4800.00 2019-09-25
# 4            105        Unknown  Customer Care  42.0  6100.00 2018-05-07
#
#    Performance Remote
# 0         87.0    Yes
# 1         73.0     No
# 2         90.0    Yes
# 3         65.0     No
# 4         82.0    Yes

# %%
#working with filtering 
#filtering more than one column

df[["Full Name", "Salary", "Performance"]]
# Out:
#        Full Name   Salary  Performance
# 0  Alice Johnson  5500.50         87.0
# 1  Micheal Smith  4800.00         73.0
# 2      Sarah Lee  4200.75         90.0
# 3      David Kim  4800.00         65.0
# 4        Unknown  6100.00         82.0
# 5     John Brown  4300.00         75.0
# 6    Emma Wilson  5800.00         88.0
# 7      Tom Davis  5000.00         82.0
# 8    Jane Miller  4700.00         79.0
# 9   Chris Taylor  4400.00         91.0

# %%
# filtering more than one column
# .iloc => filter out data base on their index number 

df .iloc[0:3, 0:3]
# Out:
#    Employment ID      Full Name Department
# 0            101  Alice Johnson         IT
# 1            102  Micheal Smith         HR
# 2            103      Sarah Lee  Marketing

# %%
# filtering more than one column
# .loc => work with label colunm with the conditional statement to filter data from the dataset 

df.loc[df["Salary"] >= 5000]
# Out:
#    Employment ID      Full Name     Department   Age  Salary  Join Date  \
# 0            101  Alice Johnson             IT  29.0  5500.5 2021-04-12
# 4            105        Unknown  Customer Care  42.0  6100.0 2018-05-07
# 6            107    Emma Wilson        Finance  33.0  5800.0 2019-01-12
# 7            108      Tom Davis      Marketing  30.0  5000.0 2020-03-22
#
#    Performance Remote
# 0         87.0    Yes
# 4         82.0    Yes
# 6         88.0    Yes
# 7         82.0    Yes

# %%
# 13/5/2026 Wednessday
#filtering more than one column

df.loc[df["Department"] == "IT"]
# Out:
#    Employment ID      Full Name Department   Age  Salary  Join Date  \
# 0            101  Alice Johnson         IT  29.0  5500.5 2021-04-12
# 3            104      David Kim         IT  31.0  4800.0 2019-09-25
#
#    Performance Remote
# 0         87.0    Yes
# 3         65.0     No

# %%
#filtering more than one column

df[df["Department"] == "IT"]
# Out:
#    Employment ID      Full Name Department   Age  Salary  Join Date  \
# 0            101  Alice Johnson         IT  29.0  5500.5 2021-04-12
# 3            104      David Kim         IT  31.0  4800.0 2019-09-25
#
#    Performance Remote
# 0         87.0    Yes
# 3         65.0     No

# %%
#filtering more than one column
df[df["Department"] != "HR"]
# Out:
#    Employment ID      Full Name     Department   Age   Salary  Join Date  \
# 0            101  Alice Johnson             IT  29.0  5500.50 2021-04-12
# 2            103      Sarah Lee      Marketing  26.0  4200.75 2022-01-18
# 3            104      David Kim             IT  31.0  4800.00 2019-09-25
# 4            105        Unknown  Customer Care  42.0  6100.00 2018-05-07
# 5            106     John Brown      Marketing  27.0  4300.00 2021-10-14
# 6            107    Emma Wilson        Finance  33.0  5800.00 2019-01-12
# 7            108      Tom Davis      Marketing  30.0  5000.00 2020-03-22
# 9            110   Chris Taylor      Marketing  28.0  4400.00 2022-05-02
#
#    Performance Remote
# 0         87.0    Yes
# 2         90.0    Yes
# 3         65.0     No
# 4         82.0    Yes
# 5         75.0     No
# 6         88.0    Yes
# 7         82.0    Yes
# 9         91.0    Yes

# %%
#filtering more than one column
df[df["Age"] > 30]
# Out:
#    Employment ID      Full Name     Department   Age  Salary  Join Date  \
# 1            102  Micheal Smith             HR  35.0  4800.0 2020-01-11
# 3            104      David Kim             IT  31.0  4800.0 2019-09-25
# 4            105        Unknown  Customer Care  42.0  6100.0 2018-05-07
# 6            107    Emma Wilson        Finance  33.0  5800.0 2019-01-12
#
#    Performance Remote
# 1         73.0     No
# 3         65.0     No
# 4         82.0    Yes
# 6         88.0    Yes

# %%
# filtering more than one column
df[
    (df["Salary"] > 50000) & (df["Remote"] == "Yes")
]
# Out:
# Empty DataFrame
# Columns: [Employment ID, Full Name, Department, Age, Salary, Join Date, Performance, Remote]
# Index: []

# %%
# filtering more than one column
df[
    (df["Salary"] > 5000) & (df["Remote"] == "Yes")
]
# Out:
#    Employment ID      Full Name     Department   Age  Salary  Join Date  \
# 0            101  Alice Johnson             IT  29.0  5500.5 2021-04-12
# 4            105        Unknown  Customer Care  42.0  6100.0 2018-05-07
# 6            107    Emma Wilson        Finance  33.0  5800.0 2019-01-12
#
#    Performance Remote
# 0         87.0    Yes
# 4         82.0    Yes
# 6         88.0    Yes

# %%
# filtering more than one column
df[
    (df["Salary"] > 5000) & (df["Remote"] == "No")
]
# Out:
# Empty DataFrame
# Columns: [Employment ID, Full Name, Department, Age, Salary, Join Date, Performance, Remote]
# Index: []

# %%
# filtering more than one column
df[
    (df["Salary"] < 5000) & (df["Remote"] == "No")
]
# Out:
#    Employment ID      Full Name Department   Age  Salary  Join Date  \
# 1            102  Micheal Smith         HR  35.0  4800.0 2020-01-11
# 3            104      David Kim         IT  31.0  4800.0 2019-09-25
# 5            106     John Brown  Marketing  27.0  4300.0 2021-10-14
#
#    Performance Remote
# 1         73.0     No
# 3         65.0     No
# 5         75.0     No

# %%
# filtering more than one column
df[
    (df["Performance"] < 50) | (df["Remote"] == "Yes")
]
# Out:
#    Employment ID      Full Name     Department   Age   Salary  Join Date  \
# 0            101  Alice Johnson             IT  29.0  5500.50 2021-04-12
# 2            103      Sarah Lee      Marketing  26.0  4200.75 2022-01-18
# 4            105        Unknown  Customer Care  42.0  6100.00 2018-05-07
# 6            107    Emma Wilson        Finance  33.0  5800.00 2019-01-12
# 7            108      Tom Davis      Marketing  30.0  5000.00 2020-03-22
# 8            109    Jane Miller             HR  30.0  4700.00 2021-05-10
# 9            110   Chris Taylor      Marketing  28.0  4400.00 2022-05-02
#
#    Performance Remote
# 0         87.0    Yes
# 2         90.0    Yes
# 4         82.0    Yes
# 6         88.0    Yes
# 7         82.0    Yes
# 8         79.0    Yes
# 9         91.0    Yes

# %%
# filtering more than one column using .isin (as membership)

df[df["Department"].isin(["IT", "Finance"])]
# Out:
#    Employment ID      Full Name Department   Age  Salary  Join Date  \
# 0            101  Alice Johnson         IT  29.0  5500.5 2021-04-12
# 3            104      David Kim         IT  31.0  4800.0 2019-09-25
# 6            107    Emma Wilson    Finance  33.0  5800.0 2019-01-12
#
#    Performance Remote
# 0         87.0    Yes
# 3         65.0     No
# 6         88.0    Yes

# %%
# filtering more than one column using .str.startswith()

df[df["Department"].str.startswith("M")]
# Out:
#    Employment ID     Full Name Department   Age   Salary  Join Date  \
# 2            103     Sarah Lee  Marketing  26.0  4200.75 2022-01-18
# 5            106    John Brown  Marketing  27.0  4300.00 2021-10-14
# 7            108     Tom Davis  Marketing  30.0  5000.00 2020-03-22
# 9            110  Chris Taylor  Marketing  28.0  4400.00 2022-05-02
#
#    Performance Remote
# 2         90.0    Yes
# 5         75.0     No
# 7         82.0    Yes
# 9         91.0    Yes

# %%
# filtering more than one column using .str.contains()

# case=False => used to cancel casing sencitivity 
df[df["Full Name"].str.contains("john", case=False)]
# Out:
#    Employment ID      Full Name Department   Age  Salary  Join Date  \
# 0            101  Alice Johnson         IT  29.0  5500.5 2021-04-12
# 5            106     John Brown  Marketing  27.0  4300.0 2021-10-14
#
#    Performance Remote
# 0         87.0    Yes
# 5         75.0     No

# %%
#sorting => Is the re-arrangement of values in ascending or desending order
#working with sorting 

df.sort_values("Salary")

#by default is to sort from the lowest to the highest  (ascending order)
# Out:
#    Employment ID      Full Name     Department   Age   Salary  Join Date  \
# 2            103      Sarah Lee      Marketing  26.0  4200.75 2022-01-18
# 5            106     John Brown      Marketing  27.0  4300.00 2021-10-14
# 9            110   Chris Taylor      Marketing  28.0  4400.00 2022-05-02
# 8            109    Jane Miller             HR  30.0  4700.00 2021-05-10
# 3            104      David Kim             IT  31.0  4800.00 2019-09-25
# 1            102  Micheal Smith             HR  35.0  4800.00 2020-01-11
# 7            108      Tom Davis      Marketing  30.0  5000.00 2020-03-22
# 0            101  Alice Johnson             IT  29.0  5500.50 2021-04-12
# 6            107    Emma Wilson        Finance  33.0  5800.00 2019-01-12
# 4            105        Unknown  Customer Care  42.0  6100.00 2018-05-07
#
#    Performance Remote
# 2         90.0    Yes
# 5         75.0     No
# 9         91.0    Yes
# 8         79.0    Yes
# 3         65.0     No
# 1         73.0     No
# ...

# %%
#sorting => Is the re-arrangement of values in assending or desending order
#working with sorting .sort_values()
#descending will sort from the highest to the lowest 
df.sort_values("Salary", ascending=False)
# Out:
#    Employment ID      Full Name     Department   Age   Salary  Join Date  \
# 4            105        Unknown  Customer Care  42.0  6100.00 2018-05-07
# 6            107    Emma Wilson        Finance  33.0  5800.00 2019-01-12
# 0            101  Alice Johnson             IT  29.0  5500.50 2021-04-12
# 7            108      Tom Davis      Marketing  30.0  5000.00 2020-03-22
# 1            102  Micheal Smith             HR  35.0  4800.00 2020-01-11
# 3            104      David Kim             IT  31.0  4800.00 2019-09-25
# 8            109    Jane Miller             HR  30.0  4700.00 2021-05-10
# 9            110   Chris Taylor      Marketing  28.0  4400.00 2022-05-02
# 5            106     John Brown      Marketing  27.0  4300.00 2021-10-14
# 2            103      Sarah Lee      Marketing  26.0  4200.75 2022-01-18
#
#    Performance Remote
# 4         82.0    Yes
# 6         88.0    Yes
# 0         87.0    Yes
# 7         82.0    Yes
# 1         73.0     No
# 3         65.0     No
# ...

# %%
#working with sorting .sort_values()

df.sort_values("Performance", ascending=False).head()
# Out:
#    Employment ID      Full Name Department   Age   Salary  Join Date  \
# 9            110   Chris Taylor  Marketing  28.0  4400.00 2022-05-02
# 2            103      Sarah Lee  Marketing  26.0  4200.75 2022-01-18
# 6            107    Emma Wilson    Finance  33.0  5800.00 2019-01-12
# 0            101  Alice Johnson         IT  29.0  5500.50 2021-04-12
# 7            108      Tom Davis  Marketing  30.0  5000.00 2020-03-22
#
#    Performance Remote
# 9         91.0    Yes
# 2         90.0    Yes
# 6         88.0    Yes
# 0         87.0    Yes
# 7         82.0    Yes

# %%
#working with sorting .sort_values()
df.sort_values("Department")
# Out:
#    Employment ID      Full Name     Department   Age   Salary  Join Date  \
# 4            105        Unknown  Customer Care  42.0  6100.00 2018-05-07
# 6            107    Emma Wilson        Finance  33.0  5800.00 2019-01-12
# 1            102  Micheal Smith             HR  35.0  4800.00 2020-01-11
# 8            109    Jane Miller             HR  30.0  4700.00 2021-05-10
# 0            101  Alice Johnson             IT  29.0  5500.50 2021-04-12
# 3            104      David Kim             IT  31.0  4800.00 2019-09-25
# 2            103      Sarah Lee      Marketing  26.0  4200.75 2022-01-18
# 5            106     John Brown      Marketing  27.0  4300.00 2021-10-14
# 7            108      Tom Davis      Marketing  30.0  5000.00 2020-03-22
# 9            110   Chris Taylor      Marketing  28.0  4400.00 2022-05-02
#
#    Performance Remote
# 4         82.0    Yes
# 6         88.0    Yes
# 1         73.0     No
# 8         79.0    Yes
# 0         87.0    Yes
# 3         65.0     No
# ...

# %%
#working with sorting .sort_values()
df.sort_values(["Department", "Performance"], ascending=[False, True])
# Out:
#    Employment ID      Full Name     Department   Age   Salary  Join Date  \
# 5            106     John Brown      Marketing  27.0  4300.00 2021-10-14
# 7            108      Tom Davis      Marketing  30.0  5000.00 2020-03-22
# 2            103      Sarah Lee      Marketing  26.0  4200.75 2022-01-18
# 9            110   Chris Taylor      Marketing  28.0  4400.00 2022-05-02
# 3            104      David Kim             IT  31.0  4800.00 2019-09-25
# 0            101  Alice Johnson             IT  29.0  5500.50 2021-04-12
# 1            102  Micheal Smith             HR  35.0  4800.00 2020-01-11
# 8            109    Jane Miller             HR  30.0  4700.00 2021-05-10
# 6            107    Emma Wilson        Finance  33.0  5800.00 2019-01-12
# 4            105        Unknown  Customer Care  42.0  6100.00 2018-05-07
#
#    Performance Remote
# 5         75.0     No
# 7         82.0    Yes
# 2         90.0    Yes
# 9         91.0    Yes
# 3         65.0     No
# 0         87.0    Yes
# ...

# %%
#working with sorting .sort_values()
df.sort_values(["Performance", "Department"], ascending=[False, True])
# Out:
#    Employment ID      Full Name     Department   Age   Salary  Join Date  \
# 9            110   Chris Taylor      Marketing  28.0  4400.00 2022-05-02
# 2            103      Sarah Lee      Marketing  26.0  4200.75 2022-01-18
# 6            107    Emma Wilson        Finance  33.0  5800.00 2019-01-12
# 0            101  Alice Johnson             IT  29.0  5500.50 2021-04-12
# 4            105        Unknown  Customer Care  42.0  6100.00 2018-05-07
# 7            108      Tom Davis      Marketing  30.0  5000.00 2020-03-22
# 8            109    Jane Miller             HR  30.0  4700.00 2021-05-10
# 5            106     John Brown      Marketing  27.0  4300.00 2021-10-14
# 1            102  Micheal Smith             HR  35.0  4800.00 2020-01-11
# 3            104      David Kim             IT  31.0  4800.00 2019-09-25
#
#    Performance Remote
# 9         91.0    Yes
# 2         90.0    Yes
# 6         88.0    Yes
# 0         87.0    Yes
# 4         82.0    Yes
# 7         82.0    Yes
# ...

# %%
#working with sorting .value_counts()

df["Department"].value_counts()
# Out:
# Department
# Marketing        4
# IT               2
# HR               2
# Customer Care    1
# Finance          1
# Name: count, dtype: int64

# %%
#working with sorting .value_counts()

df["Remote"].value_counts()
# Out:
# Remote
# Yes    7
# No     3
# Name: count, dtype: int64

# %%
# working with sorting normalize

df["Department"].value_counts(normalize=True)
# Out:
# Department
# Marketing        0.4
# IT               0.2
# HR               0.2
# Customer Care    0.1
# Finance          0.1
# Name: proportion, dtype: float64

# %%
# working with sorting normalize

df["Remote"].value_counts(normalize=True)
# Out:
# Remote
# Yes    0.7
# No     0.3
# Name: proportion, dtype: float64

# %%
# 14/5/2026  Thursday
# working with combination of dataframes

data1 = {
    "Department": ["IT", "HR", "Finance", "Marketing", "R&D", "Operations", "Sales", "Logistics", "Procurement", "Customer Service"],
    "manager": [
        "Tom Hanks", "Susan Lee", "Robert Miles", 
        "Mark Chan", "Sarah Connor", "James Nwosu", "Adaeze Obi", 
        "Daniel Smith", "Amina Yusuf", "Grace Ojo"
    ],
    "department_budget": [200000, 150000, 250000, 180000, 300000, 220000, 210000, 195000, 230000, 170000],
    "office_location": [
        "Lagos", "Abuja", "Port Harcourt", "Ibadan", "Enugu", "Kano",
        "Lagos", "Calabar", "Abuja", "Kano"
    ]
}

df1 = pd.DataFrame(data1)

df1
# Out:
#          Department       manager  department_budget office_location
# 0                IT     Tom Hanks             200000           Lagos
# 1                HR     Susan Lee             150000           Abuja
# 2           Finance  Robert Miles             250000   Port Harcourt
# 3         Marketing     Mark Chan             180000          Ibadan
# 4               R&D  Sarah Connor             300000           Enugu
# 5        Operations   James Nwosu             220000            Kano
# 6             Sales    Adaeze Obi             210000           Lagos
# 7         Logistics  Daniel Smith             195000         Calabar
# 8       Procurement   Amina Yusuf             230000           Abuja
# 9  Customer Service     Grace Ojo             170000            Kano

# %%
#convert into csv file

df1.to_csv("data/department_data.csv", index=False)

df1 = pd.read_csv("data/department_data.csv")

df1.head()
# Out:
#   Department       manager  department_budget office_location
# 0         IT     Tom Hanks             200000           Lagos
# 1         HR     Susan Lee             150000           Abuja
# 2    Finance  Robert Miles             250000   Port Harcourt
# 3  Marketing     Mark Chan             180000          Ibadan
# 4        R&D  Sarah Connor             300000           Enugu

# %%
#Merging 
#combine employee data and department data together
# default merging is inner
# how="inner"
merge_df = pd.merge(df, df1, how="inner")

merge_df
# Out:
#    Employment ID      Full Name Department   Age   Salary  Join Date  \
# 0            101  Alice Johnson         IT  29.0  5500.50 2021-04-12
# 1            102  Micheal Smith         HR  35.0  4800.00 2020-01-11
# 2            103      Sarah Lee  Marketing  26.0  4200.75 2022-01-18
# 3            104      David Kim         IT  31.0  4800.00 2019-09-25
# 4            106     John Brown  Marketing  27.0  4300.00 2021-10-14
# 5            107    Emma Wilson    Finance  33.0  5800.00 2019-01-12
# 6            108      Tom Davis  Marketing  30.0  5000.00 2020-03-22
# 7            109    Jane Miller         HR  30.0  4700.00 2021-05-10
# 8            110   Chris Taylor  Marketing  28.0  4400.00 2022-05-02
#
#    Performance Remote       manager  department_budget office_location
# 0         87.0    Yes     Tom Hanks             200000           Lagos
# 1         73.0     No     Susan Lee             150000           Abuja
# ...

# %%
df
# Out:
#    Employment ID      Full Name     Department   Age   Salary  Join Date  \
# 0            101  Alice Johnson             IT  29.0  5500.50 2021-04-12
# 1            102  Micheal Smith             HR  35.0  4800.00 2020-01-11
# 2            103      Sarah Lee      Marketing  26.0  4200.75 2022-01-18
# 3            104      David Kim             IT  31.0  4800.00 2019-09-25
# 4            105        Unknown  Customer Care  42.0  6100.00 2018-05-07
# 5            106     John Brown      Marketing  27.0  4300.00 2021-10-14
# 6            107    Emma Wilson        Finance  33.0  5800.00 2019-01-12
# 7            108      Tom Davis      Marketing  30.0  5000.00 2020-03-22
# 8            109    Jane Miller             HR  30.0  4700.00 2021-05-10
# 9            110   Chris Taylor      Marketing  28.0  4400.00 2022-05-02
#
#    Performance Remote
# 0         87.0    Yes
# 1         73.0     No
# 2         90.0    Yes
# 3         65.0     No
# 4         82.0    Yes
# 5         75.0     No
# ...

# %%
df1
# Out:
#          Department       manager  department_budget office_location
# 0                IT     Tom Hanks             200000           Lagos
# 1                HR     Susan Lee             150000           Abuja
# 2           Finance  Robert Miles             250000   Port Harcourt
# 3         Marketing     Mark Chan             180000          Ibadan
# 4               R&D  Sarah Connor             300000           Enugu
# 5        Operations   James Nwosu             220000            Kano
# 6             Sales    Adaeze Obi             210000           Lagos
# 7         Logistics  Daniel Smith             195000         Calabar
# 8       Procurement   Amina Yusuf             230000           Abuja
# 9  Customer Service     Grace Ojo             170000            Kano

# %%
#combine employee data and department data together
# how="left"
left_merge_df = pd.merge(df, df1, how="left")

left_merge_df
# Out:
#    Employment ID      Full Name     Department   Age   Salary  Join Date  \
# 0            101  Alice Johnson             IT  29.0  5500.50 2021-04-12
# 1            102  Micheal Smith             HR  35.0  4800.00 2020-01-11
# 2            103      Sarah Lee      Marketing  26.0  4200.75 2022-01-18
# 3            104      David Kim             IT  31.0  4800.00 2019-09-25
# 4            105        Unknown  Customer Care  42.0  6100.00 2018-05-07
# 5            106     John Brown      Marketing  27.0  4300.00 2021-10-14
# 6            107    Emma Wilson        Finance  33.0  5800.00 2019-01-12
# 7            108      Tom Davis      Marketing  30.0  5000.00 2020-03-22
# 8            109    Jane Miller             HR  30.0  4700.00 2021-05-10
# 9            110   Chris Taylor      Marketing  28.0  4400.00 2022-05-02
#
#    Performance Remote       manager  department_budget office_location
# 0         87.0    Yes     Tom Hanks           200000.0           Lagos
# ...

# %%
#combine employee data and department data together
# how="right"
right_merge_df = pd.merge(df, df1, how="right")

right_merge_df
# Out:
#     Employment ID      Full Name        Department   Age   Salary  Join Date  \
# 0           101.0  Alice Johnson                IT  29.0  5500.50 2021-04-12
# 1           104.0      David Kim                IT  31.0  4800.00 2019-09-25
# 2           102.0  Micheal Smith                HR  35.0  4800.00 2020-01-11
# 3           109.0    Jane Miller                HR  30.0  4700.00 2021-05-10
# 4           107.0    Emma Wilson           Finance  33.0  5800.00 2019-01-12
# 5           103.0      Sarah Lee         Marketing  26.0  4200.75 2022-01-18
# 6           106.0     John Brown         Marketing  27.0  4300.00 2021-10-14
# 7           108.0      Tom Davis         Marketing  30.0  5000.00 2020-03-22
# 8           110.0   Chris Taylor         Marketing  28.0  4400.00 2022-05-02
# 9             NaN            NaN               R&D   NaN      NaN        NaT
# 10            NaN            NaN        Operations   NaN      NaN        NaT
# ...

# %%
#combine employee data and department data together
# for full => how="outer"
full_merge_df = pd.merge(df, df1, how="outer")

full_merge_df
# Out:
#     Employment ID      Full Name        Department   Age   Salary  Join Date  \
# 0           105.0        Unknown     Customer Care  42.0  6100.00 2018-05-07
# 1             NaN            NaN  Customer Service   NaN      NaN        NaT
# 2           107.0    Emma Wilson           Finance  33.0  5800.00 2019-01-12
# 3           102.0  Micheal Smith                HR  35.0  4800.00 2020-01-11
# 4           109.0    Jane Miller                HR  30.0  4700.00 2021-05-10
# 5           101.0  Alice Johnson                IT  29.0  5500.50 2021-04-12
# 6           104.0      David Kim                IT  31.0  4800.00 2019-09-25
# 7             NaN            NaN         Logistics   NaN      NaN        NaT
# 8           103.0      Sarah Lee         Marketing  26.0  4200.75 2022-01-18
# 9           106.0     John Brown         Marketing  27.0  4300.00 2021-10-14
# 10          108.0      Tom Davis         Marketing  30.0  5000.00 2020-03-22
# ...

# %%
#average salary by department 
merge_df.groupby("Department")["Salary"].mean().sort_values(ascending=False)
# Out:
# Department
# Finance      5800.0000
# IT           5150.2500
# HR           4750.0000
# Marketing    4475.1875
# Name: Salary, dtype: float64

# %%
#find the average performance and salary by department
#sorting by salary and performance

merge_df.groupby("Department")[["Performance", "Salary"]].mean().sort_values(by=["Performance", "Salary"], ascending=[False, False])
# Out:
#             Performance     Salary
# Department
# Finance            88.0  5800.0000
# Marketing          84.5  4475.1875
# IT                 76.0  5150.2500
# HR                 76.0  4750.0000

# %%
#find the average performance and salary by department
#sorting by only salary

merge_df.groupby("Department")[["Performance", "Salary"]].mean().sort_values(by="Salary", ascending=False)
# Out:
#             Performance     Salary
# Department
# Finance            88.0  5800.0000
# IT                 76.0  5150.2500
# HR                 76.0  4750.0000
# Marketing          84.5  4475.1875

# %%
#find the average performance and salary by department
#sorting by only performance

merge_df.groupby("Department")[["Performance", "Salary"]].mean().sort_values(by="Performance", ascending=False)
# Out:
#             Performance     Salary
# Department
# Finance            88.0  5800.0000
# Marketing          84.5  4475.1875
# HR                 76.0  4750.0000
# IT                 76.0  5150.2500

# %%
# 18/05/2026  MONDAY
# write a multiple aggregation method  => .agg()

merge_df.groupby("Department").agg(

    avg_salary = ("Salary", "mean"), 
    total_salary = ("Salary", "sum"),
    employee_count = ("Salary", "count"),
    min_salary = ("Salary", "min"),
    max_salary = ("Salary", "max")

)
# Out:
#             avg_salary  total_salary  employee_count  min_salary  max_salary
# Department
# Finance      5800.0000       5800.00               1     5800.00      5800.0
# HR           4750.0000       9500.00               2     4700.00      4800.0
# IT           5150.2500      10300.50               2     4800.00      5500.5
# Marketing    4475.1875      17900.75               4     4200.75      5000.0

# %%
merge_df.groupby("Department").agg(
    avg_salary = ("Salary", "mean"),
    avg_performace = ("Performance", "mean"),
    employee_count = ("Employment ID", "count")
)
# Out:
#             avg_salary  avg_performace  employee_count
# Department
# Finance      5800.0000            88.0               1
# HR           4750.0000            76.0               2
# IT           5150.2500            76.0               2
# Marketing    4475.1875            84.5               4

# %%
# Reset index => reset_index()

merge_df.groupby("Department")["Salary"].mean().reset_index()
# Out:
#   Department     Salary
# 0    Finance  5800.0000
# 1         HR  4750.0000
# 2         IT  5150.2500
# 3  Marketing  4475.1875

# %%
# Reset index for multiple aggregation

merge_df.groupby("Department").agg(

    avg_salary = ("Salary", "mean"), 
    total_salary = ("Salary", "sum"),
    employee_count = ("Salary", "count"),
    min_salary = ("Salary", "min"),
    max_salary = ("Salary", "max")

).reset_index()
# Out:
#   Department  avg_salary  total_salary  employee_count  min_salary  max_salary
# 0    Finance   5800.0000       5800.00               1     5800.00      5800.0
# 1         HR   4750.0000       9500.00               2     4700.00      4800.0
# 2         IT   5150.2500      10300.50               2     4800.00      5500.5
# 3  Marketing   4475.1875      17900.75               4     4200.75      5000.0

# %%
# lambda => is use to create a short function or annonimous function 
# is use to create a simple function without using df  
#merge_df.groupby("Department")["Salary"].std()

merge_df.groupby("Department")["Salary"].apply(lambda x: x.std())
# Out:
# Department
# Finance             NaN
# HR            70.710678
# IT           495.328300
# Marketing    359.206497
# Name: Salary, dtype: float64

# %%
# Filtering using lamba

merge_df.groupby("Department").filter(lambda x: x["Salary"].mean() >= 5000)

#merge_df.groupby("Department")["Salary"].filter.mean() >= 5000)
# Out:
#    Employment ID      Full Name Department   Age  Salary  Join Date  \
# 0            101  Alice Johnson         IT  29.0  5500.5 2021-04-12
# 3            104      David Kim         IT  31.0  4800.0 2019-09-25
# 5            107    Emma Wilson    Finance  33.0  5800.0 2019-01-12
#
#    Performance Remote       manager  department_budget office_location
# 0         87.0    Yes     Tom Hanks             200000           Lagos
# 3         65.0     No     Tom Hanks             200000           Lagos
# 5         88.0    Yes  Robert Miles             250000   Port Harcourt

# %%
# transform 
# to add new column to the existing dataset 

merge_df["department_avg_salary"] = merge_df.groupby("Department")["Salary"].transform("mean")

merge_df
# Out:
#    Employment ID      Full Name Department   Age   Salary  Join Date  \
# 0            101  Alice Johnson         IT  29.0  5500.50 2021-04-12
# 1            102  Micheal Smith         HR  35.0  4800.00 2020-01-11
# 2            103      Sarah Lee  Marketing  26.0  4200.75 2022-01-18
# 3            104      David Kim         IT  31.0  4800.00 2019-09-25
# 4            106     John Brown  Marketing  27.0  4300.00 2021-10-14
# 5            107    Emma Wilson    Finance  33.0  5800.00 2019-01-12
# 6            108      Tom Davis  Marketing  30.0  5000.00 2020-03-22
# 7            109    Jane Miller         HR  30.0  4700.00 2021-05-10
# 8            110   Chris Taylor  Marketing  28.0  4400.00 2022-05-02
#
#    Performance Remote       manager  department_budget office_location  \
# 0         87.0    Yes     Tom Hanks             200000           Lagos
# 1         73.0     No     Susan Lee             150000           Abuja
# ...

# %%
# find the range value salary by department using lambda function 

 

merge_df.groupby("Department")["Salary"].apply(lambda x:x.max() - x.min())
# Out:
# Department
# Finance        0.00
# HR           100.00
# IT           700.50
# Marketing    799.25
# Name: Salary, dtype: float64

# %%
#19/05/2026  TUESDAY
# detect an outliers in salary column

Q1 = merge_df["Salary"].quantile(0.25)

Q3 = merge_df["Salary"].quantile(0.75)

IQR = Q3 -Q1

lower_bound = Q1 - 1.5 * IQR

upper_bound = Q3 + 1.5 * IQR

outliers = (merge_df["Salary"] < lower_bound) | (merge_df["Salary"] > upper_bound)

# %%
Q1
# Out:
# np.float64(4400.0)

# %%
Q3
# Out:
# np.float64(5000.0)

# %%
IQR
# Out:
# np.float64(600.0)

# %%
# lower bond 
lower_bound = Q1 - 1.5 * IQR

lower_bound
# Out:
# np.float64(3500.0)

# %%
# upper bond

upper_bound = Q3 + 1.5 * IQR

upper_bound
# Out:
# np.float64(5900.0)

# %%
# outliers 

outliers = (merge_df["Salary"] < lower_bound) | (merge_df["Salary"] > upper_bound)

print(outliers.sum())
# Out:
# 0

# %%
# exclude an outliers in dataframe 

Q1 = merge_df["Salary"].quantile(0.25)

Q3 = merge_df["Salary"].quantile(0.75)

IQR = Q3 -Q1

lower_bound = Q1 - 1.5 * IQR

upper_bound = Q3 + 1.5 * IQR

new_df = merge_df[
        
    (merge_df["Salary"] > lower_bound) | (merge_df["Salary"] < upper_bound)

]

new_df
# Out:
#    Employment ID      Full Name Department   Age   Salary  Join Date  \
# 0            101  Alice Johnson         IT  29.0  5500.50 2021-04-12
# 1            102  Micheal Smith         HR  35.0  4800.00 2020-01-11
# 2            103      Sarah Lee  Marketing  26.0  4200.75 2022-01-18
# 3            104      David Kim         IT  31.0  4800.00 2019-09-25
# 4            106     John Brown  Marketing  27.0  4300.00 2021-10-14
# 5            107    Emma Wilson    Finance  33.0  5800.00 2019-01-12
# 6            108      Tom Davis  Marketing  30.0  5000.00 2020-03-22
# 7            109    Jane Miller         HR  30.0  4700.00 2021-05-10
# 8            110   Chris Taylor  Marketing  28.0  4400.00 2022-05-02
#
#    Performance Remote       manager  department_budget office_location  \
# 0         87.0    Yes     Tom Hanks             200000           Lagos
# 1         73.0     No     Susan Lee             150000           Abuja
# ...

# %%
# describe will explain / calculate the sum of all the discriptive statistics in the dataset 

merge_df.describe()
# Out:
#        Employment ID        Age       Salary            Join Date  \
# count       9.000000   9.000000     9.000000                    9
# mean      105.555556  29.888889  4833.472222  2020-11-13 00:00:00
# min       101.000000  26.000000  4200.750000  2019-01-12 00:00:00
# 25%       103.000000  28.000000  4400.000000  2020-01-11 00:00:00
# 50%       106.000000  30.000000  4800.000000  2021-04-12 00:00:00
# 75%       108.000000  31.000000  5000.000000  2021-10-14 00:00:00
# max       110.000000  35.000000  5800.000000  2022-05-02 00:00:00
# std         3.205897   2.848001   536.157312                  NaN
#
#        Performance  department_budget  department_avg_salary
# count     9.000000           9.000000               9.000000
# mean     81.111111      185555.555556            4833.472222
# min      65.000000      150000.000000            4475.187500
# 25%      75.000000      180000.000000            4475.187500
# 50%      82.000000      180000.000000            4750.000000
# ...

# %%
# Visualization
# Seaborn 
# Matplotlib
# average salary by department chart 

plt.bar(merge_df["Department"], merge_df["department_avg_salary"])
plt.title("Average Salary by Department")
plt.xlabel("Department")
plt.ylabel("Salary")
plt.grid(axis="y", linestyle= "-", alpha=0.7,)

# %%
# sorting 

df_sorted = merge_df.sort_values("department_avg_salary", ascending=False)
plt.bar(df_sorted["Department"], df_sorted["department_avg_salary"])
plt.title("Average Salary by Department")
plt.xlabel("Department")
plt.ylabel("Salary")
plt.grid(axis="y", linestyle= "-", alpha=0.7,)

# %%
#Distribution proportion of remote employee

remote_status = ["Remote", "Onsite"]
plt.pie(merge_df["Remote"].value_counts(), labels=remote_status, autopct="%1.0f%%")
plt.title("Distribution proportion of remote employee")
plt.show()

# %% [markdown]
# Bar Chart
#     Uses horizontal bars to compare categories.
#     Best for comparing values across different groups.
#     Example: Comparing sales of different products.
#
# Line Chart
#     Uses lines to show trends over time.
#     Best for tracking changes or growth.
#     Example: Monthly electricity consumption.
#
# Histogram
#     Shows the distribution of numerical data using grouped intervals (bins).
#     Best for understanding frequency patterns.
#     Example: Distribution of students’ exam scores.
#
# Pie Chart
#     Displays parts of a whole as slices of a circle.
#     Best for showing percentages or proportions.
#     Example: Market share by company.
#
# Column Chart
#     Similar to a bar chart but uses vertical bars.
#     Best for comparing values across categories or time periods.
#     Example: Yearly revenue comparison.
#
# Scatter Chart

# %%
# Correlation Matrix 
# 1. Strong positive correlation => 0.5 - 1
# 2. Strong negative correlation => (-1) - (-0.5)
# 3. Weak positive correlation => 0.1 - 0.4
# 4. Weak negative correlation => (-0.4) - (-0.1) 
# 5.No correlation 0

# %%
# 20/05/2026  WEDNESSDAY

# visualize stack chart visual for average salary and department budget salary by department

plt.bar(merge_df["Department"],merge_df["department_budget"], color="lightblue", label="Budget")
plt.bar(merge_df["Department"],merge_df["department_avg_salary"], color="orange", label="Avg Salary")
plt.title("Average Salary and Departmnet Budget by Department")
plt.xlabel("Departmnet")
plt.ylabel("Avg Salary")
plt.show()

# %%
# visualize trend performance by employee

plt.plot(merge_df["Full Name"], merge_df["Performance"], color="green", marker="o")
plt.title("Performance by Employee")
plt.xlabel("Employee")
plt.ylabel("Performnace")
plt.xticks(rotation=90)
plt.grid(axis="y", linestyle= "--", alpha=0.7,)
plt.show()

# %%
# visualize the relationship between performance and salary 

plt.scatter(merge_df["Salary"], merge_df["Performance"], color="orange")
plt.title("Relationship between performance and salary")
plt.xlabel("Salary")
plt.ylabel("Performance")
plt.grid(linestyle="--", alpha=0.7)
plt.show()

# %%
# visualize correlation value
# .corr()
num_cols = ["Age", "Salary", "Performance", "department_budget", "department_avg_salary"]

corr = merge_df[num_cols].corr()

sns.heatmap(corr, annot=True, cmap="vlag", fmt=".2f")

plt.title("Correlation")
plt.show()

# %%
#visualize distribution of salary by empolyee

plt.hist(merge_df["Salary"], color="purple", bins=6, edgecolor="white")
plt.title("Distribution of salry by employee")
plt.xlabel("Salary")
plt.ylabel("Number of employee")
plt.show()

# %%
# 21/05/2025 THURSDAY
# boxplot 

sns.boxplot(merge_df["Salary"])
plt.title("Boxplot Salary Summary")
plt.show()

# %%
# Creating multiple boxplot summaries using for loop
num_cols = ["Age", "Salary", "Performance", "department_budget", "department_avg_salary"]

plt.figure(figsize=(12, 6))

for i, col in enumerate(num_cols, 1):
    plt.subplot(2, 3, i)
    sns.boxplot(merge_df[col])
    plt.title(col)
plt.tight_layout()

plt.show()

# %%
merge_df["department_avg_salary"].describe()
# Out:
# count       9.000000
# mean     4833.472222
# std       455.834298
# min      4475.187500
# 25%      4475.187500
# 50%      4750.000000
# 75%      5150.250000
# max      5800.000000
# Name: department_avg_salary, dtype: float64

# %%
merge_df["department_budget"].describe()
# Out:
# count         9.000000
# mean     185555.555556
# std       30046.260629
# min      150000.000000
# 25%      180000.000000
# 50%      180000.000000
# 75%      200000.000000
# max      250000.000000
# Name: department_budget, dtype: float64

# %%
merge_df["Age"].describe()
# Out:
# count     9.000000
# mean     29.888889
# std       2.848001
# min      26.000000
# 25%      28.000000
# 50%      30.000000
# 75%      31.000000
# max      35.000000
# Name: Age, dtype: float64

# %%
merge_df["Salary"].describe()
# Out:
# count       9.000000
# mean     4833.472222
# std       536.157312
# min      4200.750000
# 25%      4400.000000
# 50%      4800.000000
# 75%      5000.000000
# max      5800.000000
# Name: Salary, dtype: float64

# %%
merge_df["Performance"].describe()
# Out:
# count     9.000000
# mean     81.111111
# std       8.852181
# min      65.000000
# 25%      75.000000
# 50%      82.000000
# 75%      88.000000
# max      91.000000
# Name: Performance, dtype: float64

# %%
# Distribution  value for department using pie chart

dept_count = merge_df["Department"].value_counts()
fig = px.pie(
    values=dept_count.values,
    names=dept_count.index,
    title="Distribution values by Department"
)
fig.show()

# %%
dept_count = merge_df["Department"].value_counts()

dept_count
# Out:
# Department
# Marketing    4
# IT           2
# HR           2
# Finance      1
# Name: count, dtype: int64

# %%
avg_salary = merge_df.groupby("Department")["Salary"].mean().sort_values()

fig1 = px.bar(
    x=avg_salary.values,
    y=avg_salary.index,
    title="Average Salary by Depatment"

)
fig1.update_layout(xaxis_title="Salary", yaxis_title="Department")

fig1.show()

# %%
# Distribution of emoloyee performanance

fig2 = px.histogram(

    merge_df, 
    x="Performance", 
    nbins=6, 
    title="Distribution of employee performance"

)

fig2.update_traces(
    marker_line_color="white",
    marker_line_width=1
)

fig2.show()

# %%
fig3 = px.box(
    merge_df, 
    y="Salary",
    title= "Boxplot Salary"
)

fig3.show()

# %%
merge_df.to_csv("data/employee_cleaned_data.csv", index=False)
